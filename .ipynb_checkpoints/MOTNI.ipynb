# %% [markdown]
# MOT outcomes for cars in Northern Ireland during 2018-19. The data was obtained from www.opendatani.org.uk

# %%
import warnings
warnings.simplefilter('ignore', FutureWarning)

import pandas as pd
import seaborn as sns

mot = pd.read_csv('mot_outcomes.csv')

# %%
mot.values
# Out:
# array([['Armagh', 'Conducted', 53874.0, 47505.0, 6369.0, 39060.0, 4801.0,
#         205.0, 37.0, 1892.0, 523.0],
#        ['Armagh', 'Pass', 43861.0, 37888.0, 5973.0, 31133.0, 4516.0,
#         154.0, 35.0, 1472.0, 477.0],
#        ['Armagh', 'Fail', 10013.0, 9617.0, 396.0, 7927.0, 285.0, 51.0,
#         2.0, 420.0, 46.0],
#        ['Armagh', 'Pass %', 0.814140402, 0.797558152, 0.937823834,
#         0.797055812, 0.940637367, 0.751219512, 0.9459459459999999,
#         0.778012685, 0.912045889],
#        ['Ballymena', 'Conducted', 80831.0, 66979.0, 13852.0, 54819.0,
#         11488.0, 566.0, 103.0, 1635.0, 379.0],
#        ['Ballymena', 'Pass', 67407.0, 54427.0, 12980.0, 44514.0, 10772.0,
#         470.0, 96.0, 1270.0, 354.0],
#        ['Ballymena', 'Fail', 13424.0, 12552.0, 872.0, 10305.0, 716.0,
#         96.0, 7.0, 365.0, 25.0],
#        ['Ballymena', 'Pass %', 0.833925103, 0.812597978,
#         0.9370488020000001, 0.812017731, 0.937674095, 0.830388693,
#         0.932038835, 0.77675841, 0.9340369390000001],
#        ['Belfast (Balmoral)', 'Conducted', 103772.0, 88816.0, 14956.0,
#         75112.0, 12738.0, 2335.0, 577.0, 1922.0, 278.0],
#        ['Belfast (Balmoral)', 'Pass', 89610.0, 75418.0, 14192.0, 63850.0,
#         12128.0, 1885.0, 543.0, 1617.0, 254.0],
#        ['Belfast (Balmoral)', 'Fail', 14162.0, 13398.0, 764.0, 11262.0,
#         610.0, 450.0, 34.0, 305.0, 24.0],
#        ['Belfast (Balmoral)', 'Pass %', 0.863527734, 0.849148802,
#         0.948916823, 0.850063905, 0.952111791, 0.807280514,
#         0.9410745229999999, 0.841311134, 0.913669065],
#        ['Coleraine', 'Conducted', 71762.0, 61269.0, 10493.0, 52300.0,
#         8888.0, 276.0, 61.0, 1312.0, 343.0],
#        ['Coleraine', 'Pass', 59581.0, 49709.0, 9872.0, 42441.0, 8389.0,
#         207.0, 56.0, 991.0, 316.0],
#        ['Coleraine', 'Fail', 12181.0, 11560.0, 621.0, 9859.0, 499.0,
#         69.0, 5.0, 321.0, 27.0],
#        ['Coleraine', 'Pass %', 0.830258354, 0.8113238340000001,
#         0.940817688, 0.811491396, 0.943856886, 0.75, 0.918032787,
#         0.755335366, 0.9212827990000001],
#        ['Cookstown', 'Conducted', 74584.0, 61066.0, 13518.0, 49706.0,
#         11017.0, 183.0, 57.0, 2111.0, 469.0],
#        ['Cookstown', 'Pass', 61455.0, 48739.0, 12716.0, 39747.0, 10387.0,
#         0.9470042190000001, 0.828767635, 0.949212245, 0.825794033,
#         0.945454545, 0.718716578, 0.903345725],
#        ['Omagh', 'Conducted', 46002.0, 38074.0, 7928.0, 31463.0, 6405.0,
#         186.0, 66.0, 1071.0, 316.0],
#        ['Omagh', 'Pass', 38162.0, 30774.0, 7388.0, 25579.0, 6003.0,
#         130.0, 60.0, 772.0, 281.0],
#        ['Omagh', 'Fail', 7840.0, 7300.0, 540.0, 5884.0, 402.0, 56.0, 6.0,
#         299.0, 35.0],
#        ['Omagh', 'Pass %', 0.829572627, 0.808268109, 0.931886983,
#         0.812986683, 0.9372365340000001, 0.698924731, 0.9090909090000001,
#         0.7208216620000001, 0.8892405059999999]], dtype=object)

# %%
#Check to see what the first five rows of the data frame look like
mot.head()
# Out:
#   TestCentre TestDetails    All Tests  AllFullTests    AllRetests  \
# 0     Armagh   Conducted  53874.00000  47505.000000   6369.000000
# 1     Armagh        Pass  43861.00000  37888.000000   5973.000000
# 2     Armagh        Fail  10013.00000   9617.000000    396.000000
# 3     Armagh      Pass %      0.81414      0.797558      0.937824
# 4  Ballymena   Conducted  80831.00000  66979.000000  13852.000000
#
#    CarsFullTests   CarsRetests  TaxisFullTests  TaxisRetests  HGVFullTests  \
# 0   39060.000000   4801.000000       205.00000     37.000000   1892.000000
# 1   31133.000000   4516.000000       154.00000     35.000000   1472.000000
# 2    7927.000000    285.000000        51.00000      2.000000    420.000000
# 3       0.797056      0.940637         0.75122      0.945946      0.778013
# 4   54819.000000  11488.000000       566.00000    103.000000   1635.000000
#
#    HGVRetests
# 0  523.000000
# 1  477.000000
# 2   46.000000
# 3    0.912046
# 4  379.000000

# %%
mot.dtypes
# Out:
# TestCentre         object
# TestDetails        object
# All Tests         float64
# AllFullTests      float64
# AllRetests        float64
# CarsFullTests     float64
# CarsRetests       float64
# TaxisFullTests    float64
# TaxisRetests      float64
# HGVFullTests      float64
# HGVRetests        float64
# dtype: object

# %%
#I am only interested in the pass rates for cars so need to create a new dataframe
cars = mot[['TestCentre', 'TestDetails','CarsFullTests', 'CarsRetests']]
cars
# Out:
#                      TestCentre TestDetails  CarsFullTests   CarsRetests
# 0                        Armagh   Conducted   39060.000000   4801.000000
# 1                        Armagh        Pass   31133.000000   4516.000000
# 2                        Armagh        Fail    7927.000000    285.000000
# 3                        Armagh      Pass %       0.797056      0.940637
# 4                     Ballymena   Conducted   54819.000000  11488.000000
# 5                     Ballymena        Pass   44514.000000  10772.000000
# 6                     Ballymena        Fail   10305.000000    716.000000
# 7                     Ballymena      Pass %       0.812018      0.937674
# 8            Belfast (Balmoral)   Conducted   75112.000000  12738.000000
# 9            Belfast (Balmoral)        Pass   63850.000000  12128.000000
# 10           Belfast (Balmoral)        Fail   11262.000000    610.000000
# 11           Belfast (Balmoral)      Pass %       0.850064      0.952112
# 12                    Coleraine   Conducted   52300.000000   8888.000000
# 13                    Coleraine        Pass   42441.000000   8389.000000
# 14                    Coleraine        Fail    9859.000000    499.000000
# 15                    Coleraine      Pass %       0.811491      0.943857
# 16                    Cookstown   Conducted   49706.000000  11017.000000
# 17                    Cookstown        Pass   39747.000000  10387.000000
# 18                    Cookstown        Fail    9959.000000    630.000000
# 19                    Cookstown      Pass %       0.799642      0.942816
# 20                    Craigavon   Conducted   47890.000000   8171.000000
# 21                    Craigavon        Pass   38545.000000   7649.000000
# 22                    Craigavon        Fail    9345.000000    522.000000
# 23                    Craigavon      Pass %       0.804865      0.936116
# 24                  Downpatrick   Conducted   32884.000000   5938.000000
# 25                  Downpatrick        Pass   26644.000000   5612.000000
# 26                  Downpatrick        Fail    6240.000000    326.000000
# 27                  Downpatrick      Pass %       0.810242      0.945099
# 28                  Enniskillen   Conducted   35823.000000   6768.000000
# 29                  Enniskillen        Pass   28536.000000   6333.000000
# 30                  Enniskillen        Fail    7287.000000    435.000000
# 31                  Enniskillen      Pass %       0.796583      0.935727
# 32                        Larne   Conducted   36461.000000   6654.000000
# 33                        Larne        Pass   27799.000000   6229.000000
# 34                        Larne        Fail    8662.000000    425.000000
# 35                        Larne      Pass %       0.762431      0.936129
# 36                      Lisburn   Conducted   60292.000000   8766.000000
# 37                      Lisburn        Pass   50284.000000   8368.000000
# 38                      Lisburn        Fail   10008.000000    398.000000
# 39                      Lisburn      Pass %       0.834008      0.954597
# 40  Londonderry (New Buildings)   Conducted   57144.000000   8778.000000
# 41  Londonderry (New Buildings)        Pass   47310.000000   8433.000000
# 42  Londonderry (New Buildings)        Fail    9834.000000    345.000000
# 43  Londonderry (New Buildings)      Pass %       0.827908      0.960697
# 44                      Mallusk   Conducted   54430.000000  12033.000000
# 45                      Mallusk        Pass   44229.000000  11384.000000
# 46                      Mallusk        Fail   10201.000000    649.000000
# 47                      Mallusk      Pass %       0.812585      0.946065
# 48                        Newry   Conducted   51577.000000  10366.000000
# 49                        Newry        Pass   41588.000000   9866.000000
# 50                        Newry        Fail    9989.000000    500.000000
# 51                        Newry      Pass %       0.806328      0.951765
# 52                  Newtownards   Conducted   93779.000000  15614.000000
# 53                  Newtownards        Pass   77721.000000  14821.000000
# 54                  Newtownards        Fail   16058.000000    793.000000
# 55                  Newtownards      Pass %       0.828768      0.949212
# 56                        Omagh   Conducted   31463.000000   6405.000000
# 57                        Omagh        Pass   25579.000000   6003.000000
# 58                        Omagh        Fail    5884.000000    402.000000
# 59                        Omagh      Pass %       0.812987      0.937237

# %%
#Now I only need the data for pass and pass % so I create a new data frame for each
pass_rate = cars[cars['TestDetails'] == 'Pass']
percentage = cars[cars['TestDetails'] == 'Pass %']

#First I look at the pass rate
pass_rate
# Out:
#                      TestCentre TestDetails  CarsFullTests  CarsRetests
# 1                        Armagh        Pass        31133.0       4516.0
# 5                     Ballymena        Pass        44514.0      10772.0
# 9            Belfast (Balmoral)        Pass        63850.0      12128.0
# 13                    Coleraine        Pass        42441.0       8389.0
# 17                    Cookstown        Pass        39747.0      10387.0
# 21                    Craigavon        Pass        38545.0       7649.0
# 25                  Downpatrick        Pass        26644.0       5612.0
# 29                  Enniskillen        Pass        28536.0       6333.0
# 33                        Larne        Pass        27799.0       6229.0
# 37                      Lisburn        Pass        50284.0       8368.0
# 41  Londonderry (New Buildings)        Pass        47310.0       8433.0
# 45                      Mallusk        Pass        44229.0      11384.0
# 49                        Newry        Pass        41588.0       9866.0
# 53                  Newtownards        Pass        77721.0      14821.0
# 57                        Omagh        Pass        25579.0       6003.0

# %%
#I want to check what is the total number of cars passed in Northern Ireland

full_test = pass_rate['CarsFullTests']
full_test.sum()
# Out:
# 629920.0

# %%
#To see which centre has the highest number of passes I need to sort the data frame
pass_rate.sort_values('CarsFullTests', ascending=False)
# Out:
#                      TestCentre TestDetails  CarsFullTests  CarsRetests
# 53                  Newtownards        Pass        77721.0      14821.0
# 9            Belfast (Balmoral)        Pass        63850.0      12128.0
# 37                      Lisburn        Pass        50284.0       8368.0
# 41  Londonderry (New Buildings)        Pass        47310.0       8433.0
# 5                     Ballymena        Pass        44514.0      10772.0
# 45                      Mallusk        Pass        44229.0      11384.0
# 13                    Coleraine        Pass        42441.0       8389.0
# 49                        Newry        Pass        41588.0       9866.0
# 17                    Cookstown        Pass        39747.0      10387.0
# 21                    Craigavon        Pass        38545.0       7649.0
# 1                        Armagh        Pass        31133.0       4516.0
# 29                  Enniskillen        Pass        28536.0       6333.0
# 33                        Larne        Pass        27799.0       6229.0
# 25                  Downpatrick        Pass        26644.0       5612.0
# 57                        Omagh        Pass        25579.0       6003.0

# %% [markdown]
# I can see that Newtownards has the highest number of cars passed on their full test. However, this figure tells me nothing about the number of cars passed in relation to the overall total of cars going through their MOT. So I need the percentage.

# %%
percentage
# Out:
#                      TestCentre TestDetails  CarsFullTests  CarsRetests
# 3                        Armagh      Pass %       0.797056     0.940637
# 7                     Ballymena      Pass %       0.812018     0.937674
# 11           Belfast (Balmoral)      Pass %       0.850064     0.952112
# 15                    Coleraine      Pass %       0.811491     0.943857
# 19                    Cookstown      Pass %       0.799642     0.942816
# 23                    Craigavon      Pass %       0.804865     0.936116
# 27                  Downpatrick      Pass %       0.810242     0.945099
# 31                  Enniskillen      Pass %       0.796583     0.935727
# 35                        Larne      Pass %       0.762431     0.936129
# 39                      Lisburn      Pass %       0.834008     0.954597
# 43  Londonderry (New Buildings)      Pass %       0.827908     0.960697
# 47                      Mallusk      Pass %       0.812585     0.946065
# 51                        Newry      Pass %       0.806328     0.951765
# 55                  Newtownards      Pass %       0.828768     0.949212
# 59                        Omagh      Pass %       0.812987     0.937237

# %%
#I need to fix the percentage

def percent_convert(value):
    result = int(value*100)
    return result

# %%
#Checking that my function works

percent_convert(0.827908)
# Out:
# 82

# %%
passrate = percentage['CarsFullTests']
retest_rate = percentage['CarsRetests']
percentage['passrate%'] = passrate.apply(percent_convert)
percentage['retest_rate%'] = retest_rate.apply(percent_convert)
percentage
# Out:
# C:\Users\Cheryl Gamble\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Cheryl Gamble\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                      TestCentre TestDetails  CarsFullTests  CarsRetests  \
# 3                        Armagh      Pass %       0.797056     0.940637
# 7                     Ballymena      Pass %       0.812018     0.937674
# 11           Belfast (Balmoral)      Pass %       0.850064     0.952112
# 15                    Coleraine      Pass %       0.811491     0.943857
# 19                    Cookstown      Pass %       0.799642     0.942816
# 23                    Craigavon      Pass %       0.804865     0.936116
# 27                  Downpatrick      Pass %       0.810242     0.945099
# 31                  Enniskillen      Pass %       0.796583     0.935727
# 35                        Larne      Pass %       0.762431     0.936129
# 39                      Lisburn      Pass %       0.834008     0.954597
# 43  Londonderry (New Buildings)      Pass %       0.827908     0.960697
# 47                      Mallusk      Pass %       0.812585     0.946065
# 51                        Newry      Pass %       0.806328     0.951765
# 55                  Newtownards      Pass %       0.828768     0.949212
# 59                        Omagh      Pass %       0.812987     0.937237
#
#     passrate%  retest_rate%
# 3          79            94
# 7          81            93
# 11         85            95
# 15         81            94
# 19         79            94
# 23         80            93
# 27         81            94
# 31         79            93
# 35         76            93
# 39         83            95
# 43         82            96
# 47         81            94
# 51         80            95
# 55         82            94
# 59         81            93

# %%
percentage.sort_values('passrate%', ascending=False)
# Out:
#                      TestCentre TestDetails  CarsFullTests  CarsRetests  \
# 11           Belfast (Balmoral)      Pass %       0.850064     0.952112
# 39                      Lisburn      Pass %       0.834008     0.954597
# 43  Londonderry (New Buildings)      Pass %       0.827908     0.960697
# 55                  Newtownards      Pass %       0.828768     0.949212
# 7                     Ballymena      Pass %       0.812018     0.937674
# 15                    Coleraine      Pass %       0.811491     0.943857
# 27                  Downpatrick      Pass %       0.810242     0.945099
# 47                      Mallusk      Pass %       0.812585     0.946065
# 59                        Omagh      Pass %       0.812987     0.937237
# 23                    Craigavon      Pass %       0.804865     0.936116
# 51                        Newry      Pass %       0.806328     0.951765
# 3                        Armagh      Pass %       0.797056     0.940637
# 19                    Cookstown      Pass %       0.799642     0.942816
# 31                  Enniskillen      Pass %       0.796583     0.935727
# 35                        Larne      Pass %       0.762431     0.936129
#
#     passrate%  retest_rate%
# 11         85            95
# 39         83            95
# 43         82            96
# 55         82            94
# 7          81            93
# 15         81            94
# 27         81            94
# 47         81            94
# 59         81            93
# 23         80            93
# 51         80            95
# 3          79            94
# 19         79            94
# 31         79            93
# 35         76            93

# %%
#I want to visually show which centre had the highest pass rates for full tests

graph1 = sns.catplot(x='passrate%', y='TestCentre', kind='bar', data=percentage)
graph1

# %%
#Visually showing which centre had the highest pass rates for re-tests

graph2 = sns.catplot(x='retest_rate%')
